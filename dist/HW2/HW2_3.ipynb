# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
def gen_sindata(n=2):
    x = stats.uniform(-1,2) # define random variable
    v = x.rvs((n,1)) # generate sample
    y = np.sin(np.pi*v) # use sample for sine
    return (v,y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept=False)
X, y = gen_sindata(20)
lr.fit(X,y)
lr.coef_
# Out:
# array([[0.8908454]])

# %%
xi= np.linspace(-1,1,50)
yi= np.sin(np.pi*xi)
y_pred = lr.predict(xi.reshape(-1,1))

plt.plot(xi, yi,'--k',label='target')
plt.plot(X, y, 'o')
plt.plot(xi, y_pred, c='k', label='best fit')
plt.legend(loc='best')
plt.title('$a=%3.3g$' % (lr.coef_), fontsize=16)
plt.show()
# Out:
# /tmp/ipykernel_4103139/1405697935.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title('$a=%3.3g$' % (lr.coef_), fontsize=16)

# %%
cnt = 100000
#cnt = 1000
a_out=[] # output container
for i in range(cnt):
    X, y = gen_sindata(20)
    lr.fit(X,y)
    y_pred = lr.predict(xi.reshape(-1,1))
    a_out.append(lr.coef_[0,0])
a_bar = np.mean(a_out) # approx 1.43
a_var = np.var(a_out) # approx 0.71

# %%
print (a_bar, a_var)
# Out:
# 0.9871745107513527 0.04357577932229309

# %%
# confirm the variance
vsum = 0
for i in range(cnt):
    vsum += (a_out[i] - a_bar) ** 2
a_var2 = vsum / cnt
print (a_var2)
# Out:
# 0.04357577932229328

# %%
xi= np.linspace(-1,1,50)
yi= np.sin(np.pi*xi)

plt.plot(xi,(a_bar*xi-yi)**2,'--k',label='bias(x)')
plt.plot(xi,(a_var)*(xi)**2,':k',label='var(x)')
plt.plot(xi,((a_bar*xi-yi)**2 + a_var*(xi)**2),'-k',lw = 4, label='Error(x)')
plt.legend(loc='best')
plt.xlabel('x', fontsize=18)
plt.ylabel('Error',fontsize=16)
plt.title('$a_{bar}=%3.3g$, $a_{var}=%3.3g$'%(a_bar,a_var),fontsize=16)
# Out:
# Text(0.5, 1.0, '$a_{bar}=0.987$, $a_{var}=0.0436$')

# %%
# compute bias and variance
cnt = 1000000
bias = 0
var = 0
bias_squared = 0
x = np.random.uniform(-1, 1, size = cnt)


for i in range(cnt):
    bias += (a_bar*x[i] - np.sin(np.pi*x[i]))
    var += a_var * x[i] * x[i]
    bias_squared += (a_bar*x[i] - np.sin(np.pi*x[i])) ** 2


bias = bias / cnt
var = var / cnt 
bias_squared = bias_squared / cnt
error = (bias_squared + var) 

print(f'bias = {bias:.4f}, var = {var:.3f}, error = {error:.4f}')
# Out:
# bias = -0.0001, var = 0.015, error = 0.2109
